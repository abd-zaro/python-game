# %%
"""
1- this is a game, or a collection of games, called "The Games of Death". the 
user finds himself inside a weird mansion infront of the owner and the main 
antagonist in the game Dr. Villain. In order to win the game the user has to escape
the mansion by winning in three games. the first game is an object guessing
game, the second game is a trivia multiple choice questions game, the third is a luck based dice through.
If the user loses, there are a more than one way to die. I tried to keep the game lighthearted.
the game is perfectly playable to my knowledge. the formatting can be improved but I didn't have time due to unforseen technical issues
I should have added more ways to die and more questions to the lists if i had more time,
I would have also improved the story which i think is a bit too silly.
I hope you have fun playing!

"""


##IMPORTING DATABASES FOR EXIT + RANDOM FOR CHOICES AND DICE THROUGH##
from sys import exit
import random

##GAME START

def start_game():
##START SCREEN##
    print(""" 
    
    *****************************
    WELCOME TO THE GAMES OF DEATH
    *****************************
    
    """) 


    input('Press Enter to Start the game\n')
    
    introduction_scene()
    
## A SMALL INTRODUCTORY SCENE, MAINLY FOR SETTING THE TONE OF THE GAME AND CHARACTER DEVELOPMENT##

def introduction_scene ():
    
    print("""
    After a night of heavy drinking with your friends, you wake up hungover to
    find yourself tied and handcuffed in an empty, dimly lit Victorian hall.
    You hear a voice coming from the shadows...
    """)
    input(prompt = "<Press enter to continue.. >\n")
    print("""
    "AAAHH! Another victim?! looks like it's goin to be a fun night! MUAHAHAHHAHAA
    
    Tell me, simple-minded human, What is your name?"
    
    """)

##introducing dynamic variable, not used for anything important
    user_name = input('what is your name?\n')

    print(f"""

    "'{user_name}'? What kind of name is that?..."
    
    

    "Anyway, {user_name}, you are lucky! You have the honor of being my 'guest'
    for the night!
     """)
    info()
    
## SOME BACKGROUND INFO USED AS AND AN INTRODUCTION OF GAME MECHANICHS##
def info():
    print('"Are you ready for the game that will decide your fate?"')
   
    print ("""
    1) "ummm... who are you?"
    2) "game? fate? what are you talking about?"
    3) "No, I am not ready"
    4) "Yes I am ready."
    """)
# LOOP FOR CHOICES AND ANSWERS, INCLUDES DIFFERENT INPUTS THAT THE USER MIGHT ENTER    
    choice_1 = input(prompt = '<enter choice> ')
    if "1" in choice_1 or "who" in choice_1 or "you" in choice_1:
    
        print(""" 
        "I am Dr. Villain. I am aself-proclaimed genius who enjoys putting 
        people through annoying games and riddles. My servents found you 
        sleeping infront of my porch. Theydragged you here so I can have some 
        fun with you... Muahahahahha!"
        """)
        input(">>")
        info()
    
    elif "2" in choice_1 or "game" in choice_1 or "fate" in choice_1: 
        print(f"""
        "you will be asked three questions that are designed to test your 
        knowledge, intellegence and luck. You don't look very smart,but if you
        answer all my questions correctly, which I doubt, You will live to see
        another day. If you fail to answer any of my questions.. It will be your
        END! DEMISE! DOOM! MUAHAHAHAH!
        """)
        input("<Press Enter to Continue \n")
        info()
    
    elif "3" in choice_1 or "no" in choice_1 or "not" in choice_1:
        print(" You think you have a choice?? Think Again!")
        input(">> ")
        info()
    elif "4" in choice_1 or "yes" in choice_1:
        print("Excellent! Now enough talk! Let's Start!")
        input(">> ")
        question_1()
    else:
        print("Invalid Answer, Try a number 1-4")
        input(">> ")
        info()
        
#### QUESTION 1 ####

def question_1():
    print("""
    your first test will be an object guessing game. I will describe an object and you have to guess what it is.
    are you ready?
    """)
## INTRODUCING A LIST OF POSSIBLE QUESTIONS

    questions_1_bank = ['I am a container that is used to store water and other liquid.. What am I ?',
                       'I am a black and white herbivore mammal that lives in Africa.. What am I?',
                       'I am a type of material that you get from sheep, I make you warm in the winter.. What am I?']
    
## WHILE LOOP TO HAVE TWO TRIALS  

    questions = 0
    while questions < 2 :
        
##CHOOSING A RANDOM QUESTION        
            quest= random.choice(questions_1_bank)
            input('<press enter to continue>\n')
            print(quest)
            print(" ")
##QUESTION 1 DIFFERENT POSSIBLE CHOICES
            if quest == questions_1_bank[0]:

                print("enter name of the object, make sure the whole word is in lowercase")
                object_1 = input("<Enter the name of the object>\n")

                if 'bottle' in object_1 or 'Bottle' in object_1 or 'BOTTLE' in object_1:
                        print(""" You got it right! maybe you are much smarter than you look! Proceed to the next question
                        """)
                        input("<press enter to continue to question 2>\n")
                        question_2 ()
                else : 
                    questions+=1
                    if questions == 2:
                        fail ()
                    else: print("wrong! you have one more try")


            if quest == questions_1_bank[1]:

                print("enter name of the object, make sure the whole word is in lowercase")
                object_2 = input("<Enter the name of the object>\n")

                if 'zebra' in object_2 or 'Zebra' in object_2 or 'ZEBRA' in object_2:
                        print(""" You got it right! maybe you are much smarter than you look! Proceed to the next question
                        """)
                        input("<press enter to continue to question 2>\n")
                        question_2 ()
                else : 
                    questions+=1
                    if questions == 2:
                        fail ()
                    else: print("wrong! you have one more try")
            if quest == questions_1_bank[2]:

                print("enter name of the object, make sure the whole word is in lowercase")
                object_3 = input("<Enter the name of the object>\n")

                if 'wool' in object_3 or 'Wool' in object_3 or 'WOOL' in object_3:
                        print(""" You got it right! maybe you are much smarter than you look! Proceed to the next question
                        """)
                        input("<press enter to continue to question 2>\n")
                        question_2 ()
                else : 
                    questions+=1
                    if questions == 2:
                        fail ()
                    else: print("wrong! you have one more try")

              
##QUESTION 2##
def question_2 () :
                  
##INTRODUCING THE GAME##  
    print("""your second game will be a trivia game. I will ask you a question and you have to choose the right answer. 
    I will not make it easier for you this time, you only get ONE CHANCE!! """)
##Q2 LIST OF QUESTION##    
    question_2_bank = ["Who built The Great Pyramid in Giza?",
                      'Who is the only US president to serve more than two terms?',
                      'which Spanish artist drew "The Persistence of Memory?"']
## Q2 LOOPS FOR THE DIFFERENT QUESTIONS, NOTICE THAT THIS TAKES YOU TO THE FAIL FUNCTION IMMEDIATLY IF YOU CHOOSE WRONG##                  
    trivia = random.choice(question_2_bank)
    input("<press enter to get your question>")
    print(trivia)
    print(" ")
    if trivia == question_2_bank[0]:
        print("""
        choose the right answer from the following list:
        1) Khufu
        2) Khafre
        3) Menkaure
        4) Akhenaten""")
        
        trivia_1 = input('<enter choice number>\n')

        if '1' in trivia_1 or 'khufu' in trivia_1 or "Khufu" in trivia_1 or "KHUFU" in trivia_1:
                print("Wow... You actually got this right. It looks like I have understimated you. proceed to the next game")
                input("<press enter to go to the final question >\n")
                question_3()
        else:
                  fail()

    elif trivia == question_2_bank[1]:
            print("""
                  Choose the right answer from the follwing list:
                  1) George W. Bush
                  2) George H.W. Bush
                  3) Franklin D. Roosevelt
                  4) Theodore Roosevelt
                  """)

            trivia_2 = input('enter choice number\n')
            if '3' in trivia_2 or "Franklin" in trivia_2 or 'franklin' in trivia_2:
                    print("Wow... You actually got this right. It looks like I have understimated you. proceed to the next game")
                    input("press enter to go to final question \n")
                    question_3()
            else:
                        fail()

      
      
                        
    elif trivia == question_2_bank[2]:
        print("""
        Choose the right answer from the follwing list:
        1) Picasso
        2) Dali
        3) Goya
        4) Moya
        """)
        trivia_3 = input('enter choice number\n')
        if '2' in trivia_3 or "dali" in trivia_3 or "Dali" in trivia_3 or "DALI" in trivia_3:
            print("Wow... You actually got this right. It looks like I have understimated you. proceed to the next game")
            input("press enter to go to final question \n")
            question_3()
        else:
            fail()
## QUESTION THREE###            
def question_3():
 ## THE THIRD GAME IS A SIMPLE LUCK BASED GAME, I TRIED TO USE THE SAME WAY THAT WE USED IN CLASS BUT IT WAS COMPLICATED TO HAVE A FUNCTION INSIDE A FUNCTION
 ## THE USER HAS A 1/3 CHANCE OF WINNING, WHICH ISN'T UNFAIR IMO                 
    print("""
    For your final test, let's see how lucky you are! you're going to roll a 6-faced die.
    if you get a 5 or 6, I will let you go! if you don't, you will lose
    """)
    input("press enter to roll")
    dice = random.randint(1,6)
    
    if dice ==5 or dice == 6:
        print(dice)
        win()
    else:
        print(dice)
        fail()



def fail():
 ###FAIL FUNCTION
#### MORE THAN ONE WAY TO DIE, I WAS PLANNING TO DO 10 WAYS BUT THERE WAS NO TIME
                  
    print("GAME OVER. YOU HAVE DIED")
    
    death_list = ['you died by the electric chair. Toasty!',
            'Dr. Villain threw you into his personal crocodile pond',
            "you were tickled to death by Dr. Villain's servents",
                 ]
    
    death = random.choice(death_list)
    print(death)
    
    exit(0)
    
def win():
## WIN FUNCTION ##                  
    print("""
    "I can't believe it.. you won! This has never happened before!
          I am a man of my word, you are free to go!"
          You leave Dr. Villain's mansion, you live to see another day
          Congratulations!
          """) 
    exit(0)

start_game()
# Out:
#
#
#     *****************************
#     WELCOME TO THE GAMES OF DEATH
#     *****************************
#
#
# Press Enter to Start the game
#
#
#     After a night of heavy drinking with your friends, you wake up hungover to
#     find yourself tied and handcuffed in an empty, dimly lit Victorian hall.
#     You hear a voice coming from the shadows...
